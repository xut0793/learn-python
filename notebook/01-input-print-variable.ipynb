# %% [markdown]
# # 输入和输出
#
# ## 输入 input

# %%
input()
input("Number: ")
input("请输入数字：")
# Out:
#  123
# Number:  456
# 请输入数字： 789
# '789'

# %% [markdown]
# ## 输出 print

# %%
print("Hello Python")
print(123)
print(1+2)
# Out:
# Hello Python
# 123
# 3

# %% [markdown]
# ## 利用变量保存输入值

# %%
var = input("Number: ")
# 打印变量
print(var)
print(var)
print(var)
# Out:
# Number:  1234
# 1234
# 1234
# 1234

# %% [markdown]
# ## 变量

# %%
x = 123
print(x)
# Out:
# 123

# %%
y = x
print(y)
# Out:
# 123

# %%
a, b = 1,2
print(a)
print(b)
# Out:
# 1
# 2
